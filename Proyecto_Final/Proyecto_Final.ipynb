# %% [markdown]
# <a href="https://colab.research.google.com/github/gabcarmar/utec_phyton_2023/blob/main/Proyecto_Final/Proyecto_Final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd #importar libreria

# %%
# cargamos el archivo del google drive
archivo_pc = pd.read_excel('/content/drive/MyDrive/Curso Phyton/2301-M71 - 2108-Matemáticas discretas I -1074-Práctica calificada 3-Calificaciones_1.xlsx')

# %%
# head para ver los datos del excel
archivo_pc.head()
# Out:
#            Apellido        Nombre  Dirección de correo electrónico  \
# 0     ACOSTA TUESTA  Erick Rafael     erick.acosta.alu@upal.edu.pe
# 1        AÑAPE WONG  KIRK HERSHEL       kirk.anape.alu@upal.edu.pe
# 2  ATACHAGUA PORRAS   DILAN SCOTT  dilan.atachagua.alu@upal.edu.pe
# 3           CALCINA        TAYLOR   taylor.calcina.alu@upal.edu.pe
# 4       CASAS LOPEZ  DIANA LISSET      diana.casas.alu@upal.edu.pe
#
#        Estado           Iniciado el             Finalizado  \
# 0  Finalizado  2 mayo 2023  8:36 PM   2 mayo 2023  9:54 PM
# 1  Finalizado  2 mayo 2023  8:36 PM   2 mayo 2023  9:57 PM
# 2  Finalizado  2 mayo 2023  8:21 PM   2 mayo 2023  8:33 PM
# 3  Finalizado  2 mayo 2023  8:40 PM   2 mayo 2023  9:54 PM
# 4  Finalizado  2 mayo 2023  8:39 PM  2 mayo 2023  10:07 PM
#
#             Tiempo tomado  Calificación/20.00  Q. 1 /2.00  Q. 2 /2.00  \
# 0       1 hora 17 minutos                13.5         2.0         2.0
# ...

# %%
# info es para ver los datos de los columnas que tipo de dato son
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 16 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Apellido                         24 non-null     object
#  1   Nombre                           23 non-null     object
#  2   Dirección de correo electrónico  23 non-null     object
#  3   Estado                           23 non-null     object
#  4   Iniciado el                      23 non-null     object
#  5   Finalizado                       23 non-null     object
#  6   Tiempo tomado                    23 non-null     object
#  7   Calificación/20.00               24 non-null     float64
#  8   Q. 1 /2.00                       24 non-null     float64
#  9   Q. 2 /2.00                       24 non-null     float64
#  10  Q. 3 /2.00                       24 non-null     float64
#  11  Q. 4 /2.00                       24 non-null     float64
# ...

# %%
archivo_CV4= pd.read_excel('/content/drive/MyDrive/Curso Phyton/2301-M71 - 2108-Matemáticas discretas I -1074-Control Virtual 4-Calificaciones.xlsx')

# %%
archivo_CV4.head()
# Out:
#          Apellido        Nombre Dirección de correo electrónico      Estado  \
# 0   ACOSTA TUESTA  Erick Rafael    erick.acosta.alu@upal.edu.pe  Finalizado
# 1      AÑAPE WONG  KIRK HERSHEL      kirk.anape.alu@upal.edu.pe  Finalizado
# 2         CALCINA        TAYLOR  taylor.calcina.alu@upal.edu.pe  Finalizado
# 3     CASAS LOPEZ  DIANA LISSET     diana.casas.alu@upal.edu.pe  Finalizado
# 4  CHAVARRY LOPEZ  TANIA VANESA  tania.chavarry.alu@upal.edu.pe  Finalizado
#
#               Iniciado el              Finalizado           Tiempo tomado  \
# 0  23 abril 2023  6:26 PM  23 abril 2023  6:30 PM   3 minutos 35 segundos
# 1  23 abril 2023  7:38 PM  23 abril 2023  7:45 PM   7 minutos 17 segundos
# 2  22 abril 2023  9:34 PM  22 abril 2023  9:42 PM   7 minutos 58 segundos
# 3  22 abril 2023  4:35 PM  22 abril 2023  4:54 PM  18 minutos 30 segundos
# 4  23 abril 2023  4:34 PM  23 abril 2023  4:57 PM  22 minutos 51 segundos
#
#    Calificación/20.00  Q. 1 /6.00  Q. 2 /8.00  Q. 3 /6.00
# ...

# %%
archivo_CV4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 11 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Apellido                         21 non-null     object
#  1   Nombre                           20 non-null     object
#  2   Dirección de correo electrónico  20 non-null     object
#  3   Estado                           20 non-null     object
#  4   Iniciado el                      20 non-null     object
#  5   Finalizado                       20 non-null     object
#  6   Tiempo tomado                    20 non-null     object
#  7   Calificación/20.00               21 non-null     float64
#  8   Q. 1 /6.00                       21 non-null     float64
#  9   Q. 2 /8.00                       21 non-null     float64
#  10  Q. 3 /6.00                       21 non-null     float64
# dtypes: float64(4), object(7)
# memory usage: 1.9+ KB

# %%
archivo_CV4.shape
# Out:
# (21, 11)

# %%
archivo_pc.shape
# Out:
# (24, 16)

# %%
consolidado = pd.merge(archivo_pc,archivo_CV4,on='Dirección de correo electrónico')

# %%
consolidado.shape
# Out:
# (20, 26)

# %%
archivo_CV4.tail(1)
# Out:
#             Apellido Nombre Dirección de correo electrónico Estado  \
# 20  Promedio general    NaN                             NaN    NaN
#
#    Iniciado el Finalizado Tiempo tomado  Calificación/20.00  Q. 1 /6.00  \
# 20         NaN        NaN           NaN                15.2         4.8
#
#     Q. 2 /8.00  Q. 3 /6.00
# 20         5.6         4.8

# %%
consolidado = pd.merge(archivo_pc,archivo_CV4,on='Dirección de correo electrónico',how = "outer")

# %%
consolidado.shape
# Out:
# (25, 26)

# %%
consolidado.tail(3)
# Out:
#           Apellido_x            Nombre_x    Dirección de correo electrónico  \
# 22      VILLENA YNCA  ELIZABETH VERONICA  elizabeth.villena.alu@upal.edu.pe
# 23  Promedio general                 NaN                                NaN
# 24               NaN                 NaN    luis.magallanes.alu@upal.edu.pe
#
#       Estado_x         Iniciado el_x           Finalizado_x  \
# 22  Finalizado  2 mayo 2023  8:39 PM  2 mayo 2023  10:05 PM
# 23         NaN                   NaN                    NaN
# 24         NaN                   NaN                    NaN
#
#       Tiempo tomado_x  Calificación/20.00_x  Q. 1 /2.00  Q. 2 /2.00  ...  \
# 22  1 hora 26 minutos                  6.50        2.00        0.00  ...
# 23                NaN                 10.85        1.39        1.48  ...
# 24                NaN                   NaN         NaN         NaN  ...
#
#              Apellido_y            Nombre_y    Estado_y  \
# 22         VILLENA YNCA  ELIZABETH VERONICA  Finalizado
# ...

# %%
consolidado.columns
# Out:
# Index(['Apellido_x', 'Nombre_x', 'Dirección de correo electrónico', 'Estado_x',
#        'Iniciado el_x', 'Finalizado_x', 'Tiempo tomado_x',
#        'Calificación/20.00_x', 'Q. 1 /2.00', 'Q. 2 /2.00', 'Q. 3 /2.00',
#        'Q. 4 /2.00', 'Q. 5 /2.00', 'Q. 6 /3.00', 'Q. 7 /3.00', 'Q. 8 /4.00',
#        'Apellido_y', 'Nombre_y', 'Estado_y', 'Iniciado el_y', 'Finalizado_y',
#        'Tiempo tomado_y', 'Calificación/20.00_y', 'Q. 1 /6.00', 'Q. 2 /8.00',
#        'Q. 3 /6.00'],
#       dtype='object')

# %%
'luis.magallanes.alu@upal.edu.pe' in  list(archivo_pc['Dirección de correo electrónico'])
# Out:
# False

# %%
archivo_CV4[['Dirección de correo electrónico'] ]== 'luis.magallanes.alu@upal.edu.pe'
# Out:
#     Dirección de correo electrónico
# 0                             False
# 1                             False
# 2                             False
# 3                             False
# 4                             False
# 5                             False
# 6                             False
# 7                             False
# 8                             False
# 9                             False
# 10                            False
# 11                            False
# 12                            False
# 13                            False
# 14                             True
# 15                            False
# 16                            False
# 17                            False
# 18                            False
# 19                            False
# 20                            False

# %%
archivo_pc.loc[archivo_pc['Dirección de correo electrónico'] == 'luis.magallanes.alu@upal.edu.pe']
# Out:
# Empty DataFrame
# Columns: [Apellido, Nombre, Dirección de correo electrónico, Estado, Iniciado el, Finalizado, Tiempo tomado, Calificación/20.00, Q. 1 /2.00, Q. 2 /2.00, Q. 3 /2.00, Q. 4 /2.00, Q. 5 /2.00, Q. 6 /3.00, Q. 7 /3.00, Q. 8 /4.00]
# Index: []

# %%
consolidado = pd.merge(archivo_pc,archivo_CV4,on= ['Apellido','Nombre','Dirección de correo electrónico'],how = "outer")

# %%
consolidado.shape
# Out:
# (25, 24)

# %%
consolidado
# Out:
#                Apellido              Nombre  \
# 0         ACOSTA TUESTA        Erick Rafael
# 1            AÑAPE WONG        KIRK HERSHEL
# 2      ATACHAGUA PORRAS         DILAN SCOTT
# 3               CALCINA              TAYLOR
# 4           CASAS LOPEZ        DIANA LISSET
# 5        CHAVARRY LOPEZ        TANIA VANESA
# 6       Chinchay Tejada         Omar Ysmael
# 7    COCHACHES CARRANZA       NESTOR XAVIER
# 8        Correa Sanchez         Luis Alvaro
# 9    ESCOBAR VILLANUEVA      Wilder alfredo
# 10       ESPINOLA CUEVA       ROGER ANTENOR
# 11   FERNANDEZ MURAKAMI      JHORDAN STEVEN
# 12       HOLDER JIMENEZ       DIEGO ALBERTO
# 13         Horna Medina       Esdras Ismael
# 14         HUANCA ARONI             ANA LUZ
# 15        INQUEL PECHON        JOSBECK YURI
# 16         MAMANI ANDIA           LIZ ROCIO
# 17          MORAN AYALA      LADY JACKELINE
# 18     OLIVERA REATEGUI       LUIGI RICARDO
# 19      SÁNCHEZ CORDOVA          JOSÉ DAVID
# ...

# %%
consolidado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25 entries, 0 to 24
# Data columns (total 24 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Apellido                         25 non-null     object
#  1   Nombre                           24 non-null     object
#  2   Dirección de correo electrónico  24 non-null     object
#  3   Estado_x                         23 non-null     object
#  4   Iniciado el_x                    23 non-null     object
#  5   Finalizado_x                     23 non-null     object
#  6   Tiempo tomado_x                  23 non-null     object
#  7   Calificación/20.00_x             24 non-null     float64
#  8   Q. 1 /2.00                       24 non-null     float64
#  9   Q. 2 /2.00                       24 non-null     float64
#  10  Q. 3 /2.00                       24 non-null     float64
#  11  Q. 4 /2.00                       24 non-null     float64
# ...
